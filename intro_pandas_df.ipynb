# %%
# --------------------------------------------------------------------------

# ----------------- examples pandas 

# -------------------------------------------------------------------------


# ¡¡¡ --- !!! # ---> modules 

# --- system modules

import sys
import datetime
import os


# --- data handling modules

import numpy as np
import pandas as pd
import scipy.io as sp_io

# %%
# ¡¡¡ --- !!! # ---> data

df_raw = pd.read_csv('https://goz39a.s3.eu-central-1.amazonaws.com/hepatitis_csv.csv')

# fast preprocessing, dropping na to avoid errors when plotting

df = df_raw.dropna(axis=0,how = "any")
df.columns
df.shape
df
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 5     34  female    True       False   False   False    False      True
# 10    39  female   False        True   False   False    False     False
# 11    32  female    True        True    True   False    False      True
# 12    41  female    True        True    True   False    False      True
# 13    30  female    True       False    True   False    False      True
# 15    38  female   False       False    True    True     True      True
# 17    40  female   False       False    True   False    False      True
# 18    38  female    True       False   False   False    False      True
# 19    38  female   False        True   False   False    False     False
# 20    22    male    True        True    True   False    False      True
# 21    27  female    True       False    True    True     True     False
# 22    31  female    True       False   False   False    False      True
# ...

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#     age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0    34  female    True       False   False   False    False      True
# 1    39  female   False        True   False   False    False     False
# 2    32  female    True        True    True   False    False      True
# 3    41  female    True        True    True   False    False      True
# 4    30  female    True       False    True   False    False      True
# 5    38  female   False       False    True    True     True      True
# 6    40  female   False       False    True   False    False      True
# 7    38  female    True       False   False   False    False      True
# 8    38  female   False        True   False   False    False     False
# 9    22    male    True        True    True   False    False      True
# 10   27  female    True       False    True    True     True     False
# 11   31  female    True       False   False   False    False      True
# ...

# %%
df.loc[[5, 153, 154]]
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 5     34  female    True       False   False   False    False      True
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# 5        False           False   False   False   False        0.9
# 153      False            True    True   False    True        1.5
# 154      False            True    True    True   False        1.2
#
#      alk_phosphate  sgot  albumin  protime  histology class
# 5             95.0  28.0      4.0     75.0      False  live
# 153           81.0  19.0      4.1     48.0       True  live
# 154          100.0  19.0      3.1     42.0       True   die

# %%
# dir(df)
df_group1 = pd.DataFrame(df.groupby(by=["sex", "steroid"]).size())
dir(df_group1)
df_group1.index
# df_group
df_group1.loc[["female", "male"]]
df_group1_final = df_group1.reset_index(drop = False)
df_group1_final.loc[(df_group1_final["sex"]=="female") & (df_group1_final["steroid"]==False)]
df_group1_final.to_csv("test.csv") # export check for bool columns

# %%
print(df_group1)
df_group1.reset_index(inplace = True)
# Out:
#                  0
# sex    steroid
# female False    33
#        True     36
# male   False     5
#        True      6

# %%
# returning vs overwriting

my_list = [1,2,3,4,4,4,4,4,4,4,89]
# help(my_list.append)
my_list.append(-100)

# %%
my_list
# Out:
# [1, 2, 3, 4, 4, 4, 4, 4, 4, 4, 89, -100]

# %%
help(my_list.append)
help(my_list.sort)
my_list.sort()
# Out:
# Help on built-in function append:
#
# append(object, /) method of builtins.list instance
#     Append object to the end of the list.
#
# Help on built-in function sort:
#
# sort(*, key=None, reverse=False) method of builtins.list instance
#     Stable sort *IN PLACE*.

# %%
my_list
# Out:
# [-100, 1, 2, 3, 4, 4, 4, 4, 4, 4, 4, 89]

# %%
# dir(my_list)
help(my_list.count)
number_of_counts_number_4 = my_list.count(4)
my_list.count(4)
# Out:
# Help on built-in function count:
#
# count(value, /) method of builtins.list instance
#     Return number of occurrences of value.
# 7
